# %%
import numpy as np

# %%
def estimate_conditional_expectation(threshold, exponential_rate, num_samples, verbose=True):
    """
    Estimate the conditional expectation of an exponential random variable.

    Parameters:
    - threshold (float): The threshold value for conditional expectation.
    - exponential_rate (float): The rate parameter of the exponential distribution.
    - num_samples (int): The number of samples to generate.
    - verbose (bool, optional): If True, display the results. Default is True.

    Returns:
    - tuple: A tuple containing the estimated conditional expectation and the real conditional expectation.
    """

    # Generate samples from an exponential distribution with the given rate
    samples = np.random.exponential(scale=1/exponential_rate, size=num_samples)
    
    # Calculate the estimated conditional expectation
    estimated_expectation = np.mean(samples[samples > threshold])
    
    # Calculate the real conditional expectation
    real_expectation = threshold + 1/exponential_rate
    
    # Display results if verbose is set to True
    if verbose:
        print(f"""
        Parameters:
          Threshold            = {threshold}
          Exponential Rate     = {exponential_rate}
          Num Samples          = {num_samples}
        
        Results:
          Estimated Expectation = {estimated_expectation}
          Real Expectation      = {real_expectation}
          Absolute Error        = {np.abs(real_expectation - estimated_expectation)}
        """)
    
    return estimated_expectation, real_expectation

# %%
# Define a function to test different parameter values
def test_parameter_combinations():
    thresholds = [0.5, 2.0, 3.5]
    exponential_rates = [1.0, 0.5, 2.0]
    sample_sizes = [100_000, 500_000, 1_000_000]
    
    i = 1
    for threshold in thresholds:
        for exponential_rate in exponential_rates:
            for num_samples in sample_sizes:
                print(f"\nTest {i}:")
                estimate_conditional_expectation(threshold, exponential_rate, num_samples)
                i += 1

# %%
# Call the test function
test_parameter_combinations()
# Out:
# Test 1:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 1.0
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 1.4997361426480702
#           Real Expectation      = 1.5
#           Absolute Error        = 0.0002638573519297971
#
#
# Test 2:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 1.0
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 1.5011077296660196
#           Real Expectation      = 1.5
#           Absolute Error        = 0.0011077296660195746
#
#
# Test 3:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 1.0
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 1.4997807412089819
#           Real Expectation      = 1.5
#           Absolute Error        = 0.00021925879101813983
#
#
# Test 4:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 0.5
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 2.4964352151459437
#           Real Expectation      = 2.5
#           Absolute Error        = 0.003564784854056313
#
#
# Test 5:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 0.5
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 2.5027878850992633
#           Real Expectation      = 2.5
#           Absolute Error        = 0.0027878850992633097
#
#
# Test 6:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 0.5
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 2.4968032638658935
#           Real Expectation      = 2.5
#           Absolute Error        = 0.003196736134106537
#
#
# Test 7:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 2.0
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 0.9970047165876729
#           Real Expectation      = 1.0
#           Absolute Error        = 0.002995283412327132
#
#
# Test 8:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 2.0
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 1.0013377821820935
#           Real Expectation      = 1.0
#           Absolute Error        = 0.001337782182093461
#
#
# Test 9:
#
#         Parameters:
#           Threshold            = 0.5
#           Exponential Rate     = 2.0
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 1.0004742928863324
#           Real Expectation      = 1.0
#           Absolute Error        = 0.00047429288633238365
#
#
# Test 10:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 1.0
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 2.99447228574633
#           Real Expectation      = 3.0
#           Absolute Error        = 0.005527714253669824
#
#
# Test 11:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 1.0
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 2.9939929709611435
#           Real Expectation      = 3.0
#           Absolute Error        = 0.006007029038856526
#
#
# Test 12:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 1.0
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 2.9981207764669233
#           Real Expectation      = 3.0
#           Absolute Error        = 0.0018792235330766793
#
#
# Test 13:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 0.5
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 3.9896742062678134
#           Real Expectation      = 4.0
#           Absolute Error        = 0.010325793732186561
#
#
# Test 14:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 0.5
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 3.9976447213882316
#           Real Expectation      = 4.0
#           Absolute Error        = 0.00235527861176843
#
#
# Test 15:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 0.5
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 3.9959982786280657
#           Real Expectation      = 4.0
#           Absolute Error        = 0.00400172137193433
#
#
# Test 16:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 2.0
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 2.4964957172183935
#           Real Expectation      = 2.5
#           Absolute Error        = 0.003504282781606527
#
#
# Test 17:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 2.0
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 2.4937752307581773
#           Real Expectation      = 2.5
#           Absolute Error        = 0.006224769241822692
#
#
# Test 18:
#
#         Parameters:
#           Threshold            = 2.0
#           Exponential Rate     = 2.0
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 2.4954109356368877
#           Real Expectation      = 2.5
#           Absolute Error        = 0.0045890643631123496
#
#
# Test 19:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 1.0
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 4.523434366682873
#           Real Expectation      = 4.5
#           Absolute Error        = 0.023434366682873353
#
#
# Test 20:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 1.0
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 4.490836275468772
#           Real Expectation      = 4.5
#           Absolute Error        = 0.009163724531227935
#
#
# Test 21:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 1.0
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 4.50003458183308
#           Real Expectation      = 4.5
#           Absolute Error        = 3.4581833079805335e-05
#
#
# Test 22:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 0.5
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 5.490265475142554
#           Real Expectation      = 5.5
#           Absolute Error        = 0.009734524857446303
#
#
# Test 23:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 0.5
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 5.5150808961595565
#           Real Expectation      = 5.5
#           Absolute Error        = 0.015080896159556545
#
#
# Test 24:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 0.5
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 5.500349909439545
#           Real Expectation      = 5.5
#           Absolute Error        = 0.0003499094395449376
#
#
# Test 25:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 2.0
#           Num Samples          = 100000
#
#         Results:
#           Estimated Expectation = 4.05212537636465
#           Real Expectation      = 4.0
#           Absolute Error        = 0.05212537636464987
#
#
# Test 26:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 2.0
#           Num Samples          = 500000
#
#         Results:
#           Estimated Expectation = 3.9942233784900276
#           Real Expectation      = 4.0
#           Absolute Error        = 0.0057766215099723794
#
#
# Test 27:
#
#         Parameters:
#           Threshold            = 3.5
#           Exponential Rate     = 2.0
#           Num Samples          = 1000000
#
#         Results:
#           Estimated Expectation = 4.024467631929647
#           Real Expectation      = 4.0
#           Absolute Error        = 0.02446763192964685
